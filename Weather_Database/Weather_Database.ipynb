# %%
#Import the requests library 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests 
from citipy import citipy


# import the API key

from config import weather_api_key
import time 
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the lattitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []

# %%
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

        #If the city is unique, then we will add it to the cities list.\n",
    if city not in cities:
          cities.append(city)
    # Print the city count to confirms suff
    
len(cities)
# Out:
# 742

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | cidreira
# Processing Record 7 of Set 1 | krasnorechenskiy
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | khatanga
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | mayumba
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | ossora
# Processing Record 15 of Set 1 | upernavik
# Processing Record 16 of Set 1 | sitka
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | miyako
# Processing Record 19 of Set 1 | anadyr
# Processing Record 20 of Set 1 | buqayq
# City not found. Skipping...
# Processing Record 21 of Set 1 | longyearbyen
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | sibu
# Processing Record 24 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 1 | kruisfontein
# Processing Record 26 of Set 1 | montrose
# Processing Record 27 of Set 1 | vinh
# Processing Record 28 of Set 1 | abha
# Processing Record 29 of Set 1 | charters towers
# Processing Record 30 of Set 1 | banda aceh
# Processing Record 31 of Set 1 | palora
# Processing Record 32 of Set 1 | bani
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | guanambi
# Processing Record 35 of Set 1 | alta floresta
# Processing Record 36 of Set 1 | bressanone
# Processing Record 37 of Set 1 | soe
# Processing Record 38 of Set 1 | saint george
# Processing Record 39 of Set 1 | kaitangata
# Processing Record 40 of Set 1 | provideniya
# Processing Record 41 of Set 1 | kodiak
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 1 | faanui
# Processing Record 46 of Set 1 | ahuimanu
# Processing Record 47 of Set 1 | kawalu
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 2 | yorosso
# Processing Record 2 of Set 2 | saint-joseph
# Processing Record 3 of Set 2 | haines junction
# Processing Record 4 of Set 2 | esperance
# Processing Record 5 of Set 2 | tuktoyaktuk
# Processing Record 6 of Set 2 | bubaque
# Processing Record 7 of Set 2 | sao joao da barra
# Processing Record 8 of Set 2 | altay
# Processing Record 9 of Set 2 | port alfred
# Processing Record 10 of Set 2 | kozmodemyansk
# Processing Record 11 of Set 2 | komsomolskiy
# Processing Record 12 of Set 2 | umm jarr
# City not found. Skipping...
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | manokwari
# Processing Record 15 of Set 2 | vypolzovo
# Processing Record 16 of Set 2 | san policarpo
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | ca mau
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | east london
# Processing Record 21 of Set 2 | tuyen quang
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | mahebourg
# Processing Record 24 of Set 2 | klaksvik
# Processing Record 25 of Set 2 | spring hill
# Processing Record 26 of Set 2 | mountain home
# Processing Record 27 of Set 2 | ixtapa
# Processing Record 28 of Set 2 | guerrero negro
# Processing Record 29 of Set 2 | huangnihe
# Processing Record 30 of Set 2 | atar
# Processing Record 31 of Set 2 | puerto ayora
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | caravelas
# Processing Record 34 of Set 2 | zatoka
# Processing Record 35 of Set 2 | rocha
# Processing Record 36 of Set 2 | puerto del rosario
# Processing Record 37 of Set 2 | geraldton
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | darnah
# Processing Record 40 of Set 2 | port pirie
# Processing Record 41 of Set 2 | new norfolk
# Processing Record 42 of Set 2 | izhma
# Processing Record 43 of Set 2 | roma
# Processing Record 44 of Set 2 | ahipara
# Processing Record 45 of Set 2 | norman wells
# Processing Record 46 of Set 2 | muros
# Processing Record 47 of Set 2 | dingle
# Processing Record 48 of Set 2 | rongcheng
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | eskasem
# City not found. Skipping...
# Processing Record 1 of Set 3 | north branch
# Processing Record 2 of Set 3 | san quintin
# Processing Record 3 of Set 3 | andenes
# Processing Record 4 of Set 3 | hami
# Processing Record 5 of Set 3 | namatanai
# Processing Record 6 of Set 3 | wawa
# Processing Record 7 of Set 3 | libreville
# Processing Record 8 of Set 3 | chernaya kholunitsa
# Processing Record 9 of Set 3 | bethel
# Processing Record 10 of Set 3 | laguna
# Processing Record 11 of Set 3 | abonnema
# Processing Record 12 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 15 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 3 | hamilton
# Processing Record 18 of Set 3 | ancud
# Processing Record 19 of Set 3 | edmonton
# Processing Record 20 of Set 3 | saskylakh
# Processing Record 21 of Set 3 | saldanha
# Processing Record 22 of Set 3 | lebu
# Processing Record 23 of Set 3 | polyarnyy
# Processing Record 24 of Set 3 | butaritari
# Processing Record 25 of Set 3 | baghdad
# Processing Record 26 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 3 | feijo
# Processing Record 28 of Set 3 | kuusamo
# Processing Record 29 of Set 3 | chokurdakh
# Processing Record 30 of Set 3 | thompson
# Processing Record 31 of Set 3 | tessalit
# Processing Record 32 of Set 3 | coxim
# Processing Record 33 of Set 3 | tuatapere
# Processing Record 34 of Set 3 | avarua
# Processing Record 35 of Set 3 | nara
# Processing Record 36 of Set 3 | chanika
# Processing Record 37 of Set 3 | megion
# Processing Record 38 of Set 3 | kenai
# Processing Record 39 of Set 3 | villamontes
# Processing Record 40 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 41 of Set 3 | port lincoln
# Processing Record 42 of Set 3 | baykit
# Processing Record 43 of Set 3 | torbay
# Processing Record 44 of Set 3 | saint-nazaire
# Processing Record 45 of Set 3 | jamestown
# Processing Record 46 of Set 3 | nikolskoye
# Processing Record 47 of Set 3 | bermeo
# Processing Record 48 of Set 3 | chuy
# Processing Record 49 of Set 3 | grand gaube
# Processing Record 50 of Set 3 | san patricio
# Processing Record 1 of Set 4 | rio pardo de minas
# Processing Record 2 of Set 4 | dikson
# Processing Record 3 of Set 4 | lukang
# Processing Record 4 of Set 4 | poli
# Processing Record 5 of Set 4 | muravlenko
# Processing Record 6 of Set 4 | kahului
# Processing Record 7 of Set 4 | olafsvik
# Processing Record 8 of Set 4 | constitucion
# Processing Record 9 of Set 4 | airai
# Processing Record 10 of Set 4 | severobaykalsk
# Processing Record 11 of Set 4 | arlit
# Processing Record 12 of Set 4 | los llanos de aridane
# Processing Record 13 of Set 4 | yellowknife
# Processing Record 14 of Set 4 | stykkisholmur
# Processing Record 15 of Set 4 | grosse pointe farms
# Processing Record 16 of Set 4 | caluquembe
# Processing Record 17 of Set 4 | nago
# Processing Record 18 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 4 | cololaca
# Processing Record 20 of Set 4 | hilo
# Processing Record 21 of Set 4 | luderitz
# Processing Record 22 of Set 4 | hasaki
# Processing Record 23 of Set 4 | lima
# Processing Record 24 of Set 4 | nanortalik
# Processing Record 25 of Set 4 | balakhta
# Processing Record 26 of Set 4 | banjar
# Processing Record 27 of Set 4 | pangnirtung
# Processing Record 28 of Set 4 | burica
# City not found. Skipping...
# Processing Record 29 of Set 4 | antofagasta
# Processing Record 30 of Set 4 | beloha
# Processing Record 31 of Set 4 | husavik
# Processing Record 32 of Set 4 | ulladulla
# Processing Record 33 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 4 | diu
# Processing Record 35 of Set 4 | thespiai
# City not found. Skipping...
# Processing Record 36 of Set 4 | ilulissat
# Processing Record 37 of Set 4 | ahumada
# City not found. Skipping...
# Processing Record 38 of Set 4 | katsuura
# Processing Record 39 of Set 4 | mahon
# Processing Record 40 of Set 4 | moroni
# Processing Record 41 of Set 4 | pringsewu
# Processing Record 42 of Set 4 | dabat
# Processing Record 43 of Set 4 | san pedro
# Processing Record 44 of Set 4 | jalu
# Processing Record 45 of Set 4 | wiwili
# Processing Record 46 of Set 4 | kapit
# Processing Record 47 of Set 4 | redcar
# Processing Record 48 of Set 4 | ayagoz
# Processing Record 49 of Set 4 | newport
# Processing Record 50 of Set 4 | castro
# Processing Record 1 of Set 5 | kirakira
# Processing Record 2 of Set 5 | fukue
# Processing Record 3 of Set 5 | yurla
# Processing Record 4 of Set 5 | bulaevo
# Processing Record 5 of Set 5 | hofn
# Processing Record 6 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 5 | cabo san lucas
# Processing Record 8 of Set 5 | felidhoo
# City not found. Skipping...
# Processing Record 9 of Set 5 | chapais
# Processing Record 10 of Set 5 | ponta do sol
# Processing Record 11 of Set 5 | san vicente
# Processing Record 12 of Set 5 | troitsk
# Processing Record 13 of Set 5 | goderich
# Processing Record 14 of Set 5 | xihe
# Processing Record 15 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 16 of Set 5 | channel-port aux basques
# Processing Record 17 of Set 5 | caldono
# Processing Record 18 of Set 5 | nome
# Processing Record 19 of Set 5 | dunedin
# Processing Record 20 of Set 5 | plettenberg bay
# Processing Record 21 of Set 5 | yinchuan
# Processing Record 22 of Set 5 | pisco
# Processing Record 23 of Set 5 | hutang
# Processing Record 24 of Set 5 | srednekolymsk
# Processing Record 25 of Set 5 | kutum
# Processing Record 26 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 5 | labe
# Processing Record 28 of Set 5 | fortuna
# Processing Record 29 of Set 5 | denpasar
# Processing Record 30 of Set 5 | alofi
# Processing Record 31 of Set 5 | alice springs
# Processing Record 32 of Set 5 | olinda
# Processing Record 33 of Set 5 | nantucket
# Processing Record 34 of Set 5 | lethem
# Processing Record 35 of Set 5 | verkhnevilyuysk
# Processing Record 36 of Set 5 | isabela
# Processing Record 37 of Set 5 | portland
# Processing Record 38 of Set 5 | tiksi
# Processing Record 39 of Set 5 | iqaluit
# Processing Record 40 of Set 5 | mar del plata
# Processing Record 41 of Set 5 | sambava
# Processing Record 42 of Set 5 | sotouboua
# Processing Record 43 of Set 5 | ondjiva
# Processing Record 44 of Set 5 | ukiah
# Processing Record 45 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 5 | suntar
# Processing Record 47 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 5 | luxeuil-les-bains
# Processing Record 49 of Set 5 | aksarayskiy
# Processing Record 50 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 6 | palmer
# Processing Record 2 of Set 6 | vestmannaeyjar
# Processing Record 3 of Set 6 | pangody
# Processing Record 4 of Set 6 | ambon
# Processing Record 5 of Set 6 | szczytno
# Processing Record 6 of Set 6 | praia
# Processing Record 7 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 8 of Set 6 | junnar
# Processing Record 9 of Set 6 | cooma
# Processing Record 10 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 6 | nishihara
# Processing Record 12 of Set 6 | meulaboh
# Processing Record 13 of Set 6 | mahajanga
# Processing Record 14 of Set 6 | bakchar
# Processing Record 15 of Set 6 | thoen
# Processing Record 16 of Set 6 | ust-kut
# Processing Record 17 of Set 6 | beringovskiy
# Processing Record 18 of Set 6 | rio grande
# Processing Record 19 of Set 6 | litovko
# Processing Record 20 of Set 6 | roebourne
# Processing Record 21 of Set 6 | lake city
# Processing Record 22 of Set 6 | ust-ishim
# Processing Record 23 of Set 6 | flinders
# Processing Record 24 of Set 6 | aksarka
# Processing Record 25 of Set 6 | kayerkan
# Processing Record 26 of Set 6 | okhotsk
# Processing Record 27 of Set 6 | padang
# Processing Record 28 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 6 | praia da vitoria
# Processing Record 30 of Set 6 | ust-maya
# Processing Record 31 of Set 6 | tabukiniberu
# City not found. Skipping...
# Processing Record 32 of Set 6 | kijang
# Processing Record 33 of Set 6 | cayenne
# Processing Record 34 of Set 6 | chicama
# Processing Record 35 of Set 6 | yulara
# Processing Record 36 of Set 6 | cherskiy
# Processing Record 37 of Set 6 | camacha
# Processing Record 38 of Set 6 | preobrazheniye
# Processing Record 39 of Set 6 | praya
# Processing Record 40 of Set 6 | belmonte
# Processing Record 41 of Set 6 | yar-sale
# Processing Record 42 of Set 6 | karabanovo
# Processing Record 43 of Set 6 | olpad
# Processing Record 44 of Set 6 | aykhal
# Processing Record 45 of Set 6 | necochea
# Processing Record 46 of Set 6 | kozhevnikovo
# Processing Record 47 of Set 6 | clyde river
# Processing Record 48 of Set 6 | lasem
# Processing Record 49 of Set 6 | lompoc
# Processing Record 50 of Set 6 | tchollire
# Processing Record 1 of Set 7 | kodinsk
# Processing Record 2 of Set 7 | sept-iles
# Processing Record 3 of Set 7 | cavalcante
# Processing Record 4 of Set 7 | nipawin
# Processing Record 5 of Set 7 | sadat
# Processing Record 6 of Set 7 | victoria
# Processing Record 7 of Set 7 | lavrentiya
# Processing Record 8 of Set 7 | sulangan
# Processing Record 9 of Set 7 | znamenskoye
# Processing Record 10 of Set 7 | port hardy
# Processing Record 11 of Set 7 | namwala
# Processing Record 12 of Set 7 | udachnyy
# Processing Record 13 of Set 7 | ribeira grande
# Processing Record 14 of Set 7 | dargaville
# Processing Record 15 of Set 7 | krasnoselkup
# Processing Record 16 of Set 7 | aklavik
# Processing Record 17 of Set 7 | york
# Processing Record 18 of Set 7 | izoplit
# Processing Record 19 of Set 7 | atambua
# Processing Record 20 of Set 7 | ust-ordynskiy
# Processing Record 21 of Set 7 | bilma
# Processing Record 22 of Set 7 | sheregesh
# Processing Record 23 of Set 7 | elko
# Processing Record 24 of Set 7 | severo-kurilsk
# Processing Record 25 of Set 7 | tigbao
# Processing Record 26 of Set 7 | makurdi
# Processing Record 27 of Set 7 | henties bay
# Processing Record 28 of Set 7 | lujiang
# Processing Record 29 of Set 7 | auki
# Processing Record 30 of Set 7 | avera
# Processing Record 31 of Set 7 | voznesenskoye
# Processing Record 32 of Set 7 | port augusta
# Processing Record 33 of Set 7 | pevek
# Processing Record 34 of Set 7 | ellisras
# Processing Record 35 of Set 7 | tura
# Processing Record 36 of Set 7 | codrington
# Processing Record 37 of Set 7 | fairbanks
# Processing Record 38 of Set 7 | svetlyy
# Processing Record 39 of Set 7 | odder
# Processing Record 40 of Set 7 | chaiya
# Processing Record 41 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 7 | port elizabeth
# Processing Record 43 of Set 7 | kandalaksha
# Processing Record 44 of Set 7 | marzuq
# Processing Record 45 of Set 7 | isangel
# Processing Record 46 of Set 7 | bambous virieux
# Processing Record 47 of Set 7 | rio gallegos
# Processing Record 48 of Set 7 | tapanatepec
# City not found. Skipping...
# Processing Record 49 of Set 7 | russell
# Processing Record 50 of Set 7 | abu samrah
# Processing Record 1 of Set 8 | tokat
# Processing Record 2 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 8 | wanning
# Processing Record 4 of Set 8 | rudnichnyy
# Processing Record 5 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 6 of Set 8 | two hills
# Processing Record 7 of Set 8 | yangjiang
# Processing Record 8 of Set 8 | binga
# Processing Record 9 of Set 8 | bengkulu
# Processing Record 10 of Set 8 | eydhafushi
# Processing Record 11 of Set 8 | batagay
# Processing Record 12 of Set 8 | jilib
# Processing Record 13 of Set 8 | aranos
# Processing Record 14 of Set 8 | martinsville
# Processing Record 15 of Set 8 | nizhniy odes
# Processing Record 16 of Set 8 | mehamn
# Processing Record 17 of Set 8 | alenquer
# Processing Record 18 of Set 8 | jiwani
# Processing Record 19 of Set 8 | polovinnoye
# Processing Record 20 of Set 8 | rundu
# Processing Record 21 of Set 8 | aksu
# Processing Record 22 of Set 8 | taoudenni
# Processing Record 23 of Set 8 | sahrak
# City not found. Skipping...
# Processing Record 24 of Set 8 | san cristobal
# Processing Record 25 of Set 8 | caazapa
# Processing Record 26 of Set 8 | gat
# Processing Record 27 of Set 8 | fugen
# Processing Record 28 of Set 8 | port macquarie
# Processing Record 29 of Set 8 | nioro
# Processing Record 30 of Set 8 | durusu
# Processing Record 31 of Set 8 | hambantota
# Processing Record 32 of Set 8 | labuhan
# Processing Record 33 of Set 8 | longview
# Processing Record 34 of Set 8 | mamlyutka
# Processing Record 35 of Set 8 | sembakung
# Processing Record 36 of Set 8 | coquimbo
# Processing Record 37 of Set 8 | ketchikan
# Processing Record 38 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 8 | severomuysk
# Processing Record 40 of Set 8 | gabrovo
# Processing Record 41 of Set 8 | kayseri
# Processing Record 42 of Set 8 | zapolyarnyy
# Processing Record 43 of Set 8 | celestun
# Processing Record 44 of Set 8 | eregli
# Processing Record 45 of Set 8 | sioux lookout
# Processing Record 46 of Set 8 | cairns
# Processing Record 47 of Set 8 | rengo
# Processing Record 48 of Set 8 | mumbwa
# Processing Record 49 of Set 8 | zhanaozen
# Processing Record 50 of Set 8 | ordynskoye
# Processing Record 1 of Set 9 | novokayakent
# Processing Record 2 of Set 9 | kupang
# Processing Record 3 of Set 9 | puerto narino
# Processing Record 4 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 9 | bouna
# Processing Record 7 of Set 9 | bayeux
# Processing Record 8 of Set 9 | zhigansk
# Processing Record 9 of Set 9 | mount gambier
# Processing Record 10 of Set 9 | the valley
# Processing Record 11 of Set 9 | palana
# Processing Record 12 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 9 | mayo
# Processing Record 14 of Set 9 | monrovia
# Processing Record 15 of Set 9 | riyadh
# Processing Record 16 of Set 9 | tombouctou
# Processing Record 17 of Set 9 | muisne
# Processing Record 18 of Set 9 | kifri
# Processing Record 19 of Set 9 | sao filipe
# Processing Record 20 of Set 9 | coihaique
# Processing Record 21 of Set 9 | kautokeino
# Processing Record 22 of Set 9 | kamyshevatskaya
# Processing Record 23 of Set 9 | namanga
# Processing Record 24 of Set 9 | nelson bay
# Processing Record 25 of Set 9 | mirnyy
# Processing Record 26 of Set 9 | berlevag
# Processing Record 27 of Set 9 | moerai
# Processing Record 28 of Set 9 | camana
# Processing Record 29 of Set 9 | lagoa
# Processing Record 30 of Set 9 | port keats
# Processing Record 31 of Set 9 | kavieng
# Processing Record 32 of Set 9 | moree
# Processing Record 33 of Set 9 | matagami
# Processing Record 34 of Set 9 | estelle
# Processing Record 35 of Set 9 | khandbari
# Processing Record 36 of Set 9 | miraflores
# Processing Record 37 of Set 9 | valday
# Processing Record 38 of Set 9 | gurskoye
# City not found. Skipping...
# Processing Record 39 of Set 9 | muncar
# Processing Record 40 of Set 9 | inuvik
# Processing Record 41 of Set 9 | agirish
# Processing Record 42 of Set 9 | filadelfia
# Processing Record 43 of Set 9 | sinnamary
# Processing Record 44 of Set 9 | dauphin
# Processing Record 45 of Set 9 | cabedelo
# Processing Record 46 of Set 9 | columbus
# Processing Record 47 of Set 9 | ambatondrazaka
# Processing Record 48 of Set 9 | jemnice
# Processing Record 49 of Set 9 | pithoragarh
# Processing Record 50 of Set 9 | issoire
# Processing Record 1 of Set 10 | mantua
# Processing Record 2 of Set 10 | miandrivazo
# Processing Record 3 of Set 10 | omboue
# Processing Record 4 of Set 10 | namibe
# Processing Record 5 of Set 10 | doctor juan leon mallorquin
# Processing Record 6 of Set 10 | saint-georges
# Processing Record 7 of Set 10 | marsa matruh
# Processing Record 8 of Set 10 | poum
# Processing Record 9 of Set 10 | lazarev
# Processing Record 10 of Set 10 | morondava
# Processing Record 11 of Set 10 | richards bay
# Processing Record 12 of Set 10 | orotukan
# Processing Record 13 of Set 10 | hibbing
# Processing Record 14 of Set 10 | aljezur
# Processing Record 15 of Set 10 | bethalto
# Processing Record 16 of Set 10 | amahai
# Processing Record 17 of Set 10 | santa isabel
# Processing Record 18 of Set 10 | plon
# Processing Record 19 of Set 10 | tabou
# Processing Record 20 of Set 10 | viedma
# Processing Record 21 of Set 10 | coari
# Processing Record 22 of Set 10 | solnechnyy
# Processing Record 23 of Set 10 | samarai
# Processing Record 24 of Set 10 | narsaq
# Processing Record 25 of Set 10 | surt
# Processing Record 26 of Set 10 | nemuro
# Processing Record 27 of Set 10 | soldotna
# Processing Record 28 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 10 | king city
# Processing Record 30 of Set 10 | merauke
# Processing Record 31 of Set 10 | tambura
# Processing Record 32 of Set 10 | vila franca do campo
# Processing Record 33 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 34 of Set 10 | saint-hyacinthe
# Processing Record 35 of Set 10 | la paz
# Processing Record 36 of Set 10 | phnum penh
# City not found. Skipping...
# Processing Record 37 of Set 10 | los algarrobos
# Processing Record 38 of Set 10 | bucerias
# Processing Record 39 of Set 10 | pacific grove
# Processing Record 40 of Set 10 | uvalde
# Processing Record 41 of Set 10 | garowe
# Processing Record 42 of Set 10 | touros
# Processing Record 43 of Set 10 | alugan
# Processing Record 44 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 45 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 46 of Set 10 | souillac
# Processing Record 47 of Set 10 | tobermory
# Processing Record 48 of Set 10 | altamont
# Processing Record 49 of Set 10 | butembo
# Processing Record 50 of Set 10 | tharrawaddy
# City not found. Skipping...
# Processing Record 1 of Set 11 | tilichiki
# Processing Record 2 of Set 11 | msowero
# Processing Record 3 of Set 11 | arman
# Processing Record 4 of Set 11 | barra do bugres
# Processing Record 5 of Set 11 | ankazoabo
# Processing Record 6 of Set 11 | naze
# Processing Record 7 of Set 11 | enshi
# Processing Record 8 of Set 11 | emba
# Processing Record 9 of Set 11 | sanandaj
# Processing Record 10 of Set 11 | dibaya
# City not found. Skipping...
# Processing Record 11 of Set 11 | eloy
# Processing Record 12 of Set 11 | borogontsy
# Processing Record 13 of Set 11 | port moresby
# Processing Record 14 of Set 11 | chimbote
# Processing Record 15 of Set 11 | ondangwa
# Processing Record 16 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 17 of Set 11 | anori
# Processing Record 18 of Set 11 | santa isabel do rio negro
# Processing Record 19 of Set 11 | huarmey
# Processing Record 20 of Set 11 | gerash
# Processing Record 21 of Set 11 | devils lake
# Processing Record 22 of Set 11 | saint-augustin
# Processing Record 23 of Set 11 | lapua
# Processing Record 24 of Set 11 | jiangyou
# Processing Record 25 of Set 11 | broken hill
# Processing Record 26 of Set 11 | tsumeb
# Processing Record 27 of Set 11 | viseu
# Processing Record 28 of Set 11 | karlovac
# Processing Record 29 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 11 | gondanglegi
# Processing Record 31 of Set 11 | colquechaca
# Processing Record 32 of Set 11 | batagay-alyta
# Processing Record 33 of Set 11 | podlesnoye
# Processing Record 34 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 35 of Set 11 | liverpool
# Processing Record 36 of Set 11 | izsak
# Processing Record 37 of Set 11 | japura
# Processing Record 38 of Set 11 | tromso
# Processing Record 39 of Set 11 | sibolga
# Processing Record 40 of Set 11 | poltar
# Processing Record 41 of Set 11 | talaya
# Processing Record 42 of Set 11 | urengoy
# Processing Record 43 of Set 11 | calama
# Processing Record 44 of Set 11 | shahreza
# Processing Record 45 of Set 11 | dvinskoy
# Processing Record 46 of Set 11 | aguimes
# Processing Record 47 of Set 11 | saint anthony
# Processing Record 48 of Set 11 | katangli
# Processing Record 49 of Set 11 | eureka
# Processing Record 50 of Set 11 | madisonville
# Processing Record 1 of Set 12 | ciudad bolivar
# Processing Record 2 of Set 12 | mikhaylov
# Processing Record 3 of Set 12 | tamandare
# Processing Record 4 of Set 12 | hudiksvall
# Processing Record 5 of Set 12 | yeniseysk
# Processing Record 6 of Set 12 | jubayl
# City not found. Skipping...
# Processing Record 7 of Set 12 | indian head
# Processing Record 8 of Set 12 | kieta
# Processing Record 9 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 12 | peniche
# Processing Record 12 of Set 12 | talnakh
# Processing Record 13 of Set 12 | deputatskiy
# Processing Record 14 of Set 12 | almaznyy
# Processing Record 15 of Set 12 | cedar city
# Processing Record 16 of Set 12 | port-gentil
# Processing Record 17 of Set 12 | quatre cocos
# Processing Record 18 of Set 12 | bonavista
# Processing Record 19 of Set 12 | sorland
# Processing Record 20 of Set 12 | leningradskiy
# Processing Record 21 of Set 12 | cockburn town
# Processing Record 22 of Set 12 | kenora
# Processing Record 23 of Set 12 | adrar
# Processing Record 24 of Set 12 | yining
# Processing Record 25 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 26 of Set 12 | fuerte olimpo
# Processing Record 27 of Set 12 | vao
# Processing Record 28 of Set 12 | barentu
# Processing Record 29 of Set 12 | nizhniy kuranakh
# Processing Record 30 of Set 12 | port blair
# Processing Record 31 of Set 12 | oshkosh
# Processing Record 32 of Set 12 | tiarei
# Processing Record 33 of Set 12 | tabas
# Processing Record 34 of Set 12 | bulawayo
# Processing Record 35 of Set 12 | morant bay
# Processing Record 36 of Set 12 | milingimbi
# City not found. Skipping...
# Processing Record 37 of Set 12 | glenwood springs
# Processing Record 38 of Set 12 | margate
# Processing Record 39 of Set 12 | buala
# Processing Record 40 of Set 12 | sukumo
# Processing Record 41 of Set 12 | oshikango
# Processing Record 42 of Set 12 | weligama
# Processing Record 43 of Set 12 | mitchell
# Processing Record 44 of Set 12 | homer
# Processing Record 45 of Set 12 | sao domingos
# Processing Record 46 of Set 12 | riviere-au-renard
# Processing Record 47 of Set 12 | karaton
# Processing Record 48 of Set 12 | bereda
# Processing Record 49 of Set 12 | korla
# Processing Record 50 of Set 12 | porbandar
# Processing Record 1 of Set 13 | koping
# Processing Record 2 of Set 13 | bentiu
# Processing Record 3 of Set 13 | pacifica
# Processing Record 4 of Set 13 | miass
# Processing Record 5 of Set 13 | la romana
# Processing Record 6 of Set 13 | dryden
# Processing Record 7 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 13 | kokoda
# Processing Record 9 of Set 13 | bilibino
# Processing Record 10 of Set 13 | takoradi
# Processing Record 11 of Set 13 | arrecife
# Processing Record 12 of Set 13 | guira de melena
# Processing Record 13 of Set 13 | bambamarca
# Processing Record 14 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 15 of Set 13 | kachiry
# Processing Record 16 of Set 13 | vysokogornyy
# Processing Record 17 of Set 13 | isilkul
# Processing Record 18 of Set 13 | progreso
# Processing Record 19 of Set 13 | belaya gora
# Processing Record 20 of Set 13 | forestville
# Processing Record 21 of Set 13 | uglovskoye
# Processing Record 22 of Set 13 | vredendal
# Processing Record 23 of Set 13 | balikpapan
# Processing Record 24 of Set 13 | nouadhibou
# Processing Record 25 of Set 13 | son la
# Processing Record 26 of Set 13 | atherton
# Processing Record 27 of Set 13 | caconda
# Processing Record 28 of Set 13 | amapa
# Processing Record 29 of Set 13 | luena
# Processing Record 30 of Set 13 | haapu
# City not found. Skipping...
# Processing Record 31 of Set 13 | ashcroft
# Processing Record 32 of Set 13 | nanakuli
# Processing Record 33 of Set 13 | pudozh
# Processing Record 34 of Set 13 | porto torres
# Processing Record 35 of Set 13 | primorsk
# Processing Record 36 of Set 13 | derzhavinsk
# Processing Record 37 of Set 13 | oranjestad
# Processing Record 38 of Set 13 | kasra
# City not found. Skipping...
# Processing Record 39 of Set 13 | tomohon
# Processing Record 40 of Set 13 | liwale
# Processing Record 41 of Set 13 | kalikino
# Processing Record 42 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 13 | wenling
# Processing Record 44 of Set 13 | kavaratti
# Processing Record 45 of Set 13 | cobourg
# Processing Record 46 of Set 13 | moose factory
# Processing Record 47 of Set 13 | nokaneng
# Processing Record 48 of Set 13 | iznik
# Processing Record 49 of Set 13 | teya
# Processing Record 50 of Set 13 | phimai
# Processing Record 1 of Set 14 | brae
# Processing Record 2 of Set 14 | mabaruma
# Processing Record 3 of Set 14 | cap malheureux
# Processing Record 4 of Set 14 | kaeo
# Processing Record 5 of Set 14 | turayf
# Processing Record 6 of Set 14 | anakan
# Processing Record 7 of Set 14 | staunton
# Processing Record 8 of Set 14 | qasigiannguit
# Processing Record 9 of Set 14 | grindavik
# Processing Record 10 of Set 14 | chingirlau
# Processing Record 11 of Set 14 | sakakah
# Processing Record 12 of Set 14 | asau
# Processing Record 13 of Set 14 | naugarzan
# City not found. Skipping...
# Processing Record 14 of Set 14 | tra vinh
# Processing Record 15 of Set 14 | imperial beach
# Processing Record 16 of Set 14 | sao felix do xingu
# Processing Record 17 of Set 14 | huilong
# Processing Record 18 of Set 14 | jumla
# Processing Record 19 of Set 14 | bom jesus
# Processing Record 20 of Set 14 | zhezkazgan
# Processing Record 21 of Set 14 | gaeta
# Processing Record 22 of Set 14 | jaunjelgava
# Processing Record 23 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 24 of Set 14 | warrnambool
# Processing Record 25 of Set 14 | macomb
# Processing Record 26 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 27 of Set 14 | pavlovsk
# Processing Record 28 of Set 14 | itarema
# Processing Record 29 of Set 14 | januaria
# Processing Record 30 of Set 14 | seredka
# Processing Record 31 of Set 14 | ishigaki
# Processing Record 32 of Set 14 | tamale
# Processing Record 33 of Set 14 | lipin bor
# Processing Record 34 of Set 14 | manuk mangkaw
# Processing Record 35 of Set 14 | thilogne
# City not found. Skipping...
# Processing Record 36 of Set 14 | shar
# Processing Record 37 of Set 14 | makanya
# Processing Record 38 of Set 14 | zhangjiakou
# Processing Record 39 of Set 14 | dongsheng
# Processing Record 40 of Set 14 | coalcoman
# City not found. Skipping...
# Processing Record 41 of Set 14 | boa vista
# Processing Record 42 of Set 14 | wasilla
# Processing Record 43 of Set 14 | shache
# Processing Record 44 of Set 14 | moindou
# Processing Record 45 of Set 14 | kihei
# Processing Record 46 of Set 14 | bac lieu
# Processing Record 47 of Set 14 | saint-pierre
# Processing Record 48 of Set 14 | la ronge
# Processing Record 49 of Set 14 | maputo
# Processing Record 50 of Set 14 | bettiah
# Processing Record 1 of Set 15 | healdsburg
# Processing Record 2 of Set 15 | paranhos
# Processing Record 3 of Set 15 | solsvik
# City not found. Skipping...
# Processing Record 4 of Set 15 | buena vista
# Processing Record 5 of Set 15 | egvekinot
# Processing Record 6 of Set 15 | faya
# Processing Record 7 of Set 15 | onega
# Processing Record 8 of Set 15 | luba
# Processing Record 9 of Set 15 | tiznit
# Processing Record 10 of Set 15 | tatarbunary
# Processing Record 11 of Set 15 | blyznyuky
# Processing Record 12 of Set 15 | great bend
# Processing Record 13 of Set 15 | presidencia roque saenz pena
# Processing Record 14 of Set 15 | sur
# Processing Record 15 of Set 15 | takayama
# Processing Record 16 of Set 15 | soyo
# Processing Record 17 of Set 15 | hervey bay
# Processing Record 18 of Set 15 | coruripe
# Processing Record 19 of Set 15 | bouar
# Processing Record 20 of Set 15 | gao
# Processing Record 21 of Set 15 | taybad
# Processing Record 22 of Set 15 | hammerfest
# Processing Record 23 of Set 15 | anjangaon
# Processing Record 24 of Set 15 | bandarbeyla
# Processing Record 25 of Set 15 | coahuayana
# Processing Record 26 of Set 15 | vila velha
# Processing Record 27 of Set 15 | dasoguz
# Processing Record 28 of Set 15 | paamiut
# Processing Record 29 of Set 15 | shwebo
# Processing Record 30 of Set 15 | dakar
# Processing Record 31 of Set 15 | stankov
# Processing Record 32 of Set 15 | toora-khem
# Processing Record 33 of Set 15 | whyalla
# Processing Record 34 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 15 | erenhot
# Processing Record 36 of Set 15 | te anau
# Processing Record 37 of Set 15 | villa carlos paz
# Processing Record 38 of Set 15 | shimanovsk
# Processing Record 39 of Set 15 | marquette
# Processing Record 40 of Set 15 | petatlan
# Processing Record 41 of Set 15 | oktyabrskoye
# Processing Record 42 of Set 15 | comodoro rivadavia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Qaanaaq      GL  77.4840  -69.3632     -7.82        95
# 1            Atuona      PF  -9.8000 -139.0333     77.74        75
# 2    Saint-Philippe      RE -21.3585   55.7679     83.79        84
# 3           Mataura      NZ -46.1927  168.8643     50.49        99
# 4          Cidreira      BR -30.1811  -50.2056     74.66        57
# 5  Krasnorechenskiy      RU  44.6265  135.3532      5.63        93
# 6            Albany      US  42.6001  -73.9662     34.38        92
# 7          Khatanga      RU  71.9667  102.5000     -1.26        82
# 8           Ushuaia      AR -54.8000  -68.3000     47.82        87
# 9      Punta Arenas      CL -53.1500  -70.9167     50.02        76
#
#    Cloudiness  Wind Speed Current Description
# 0         100        7.25     overcast clouds
# 1           9       17.11           clear sky
# 2          64        9.17       broken clouds
# 3          27        2.80    scattered clouds
# 4           0       13.65           clear sky
# 5          53        7.07       broken clouds
# 6          91        1.01     overcast clouds
# 7         100       16.96     overcast clouds
# 8          75       26.46       broken clouds
# 9          75       18.41          light rain

# %%
#Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
#Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
